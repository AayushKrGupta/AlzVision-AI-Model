# %%
# !pip install tensorflow pillow matplotlib scikit-learn
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting pillow
#   Using cached pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from tensorflow) (26.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in ./venv/lib/python3.12/site-packages (from tensorflow) (82.0.0)
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in ./venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.78.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.13.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy>=1.26.0 (from tensorflow)
#   Using cached numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.15.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.0 kB/s eta 0:00:00 kB/s eta 0:00:03:04
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Downloading rich-14.3.2-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in ./venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB ? eta 0:00:00MB/s eta 0:00:010:00:03m
# Using cached pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 1.8 MB/s eta 0:00:000:00:0136m0:00:01
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.1 MB/s eta 0:00:00
# Downloading grpcio-1.78.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading h5py-3.15.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 6.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading keras-3.13.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 7.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Using cached numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.9 MB/s eta 0:00:00
# Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.5/323.5 kB 10.5 MB/s eta 0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 7.2 MB/s eta 0:00:00
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 kB 6.2 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading werkzeug-3.1.5-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 7.1 MB/s eta 0:00:00
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (408 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.2/408.2 kB 7.0 MB/s eta 0:00:000 MB/s eta 0:00:01
# Downloading rich-14.3.2-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.0/310.0 kB 7.0 MB/s eta 0:00:007.0 MB/s eta 0:00:01
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 5.8 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, werkzeug, threadpoolctl, termcolor, tensorboard-data-server, pyparsing, protobuf, pillow, optree, opt_einsum, numpy, mdurl, markdown, kiwisolver, joblib, grpcio, google_pasta, gast, fonttools, cycler, absl-py, tensorboard, scipy, ml_dtypes, markdown-it-py, h5py, contourpy, astunparse, scikit-learn, rich, matplotlib, keras, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.61.1 gast-0.7.0 google_pasta-0.2.0 grpcio-1.78.0 h5py-3.15.1 joblib-1.5.3 keras-3.13.2 kiwisolver-1.4.9 libclang-18.1.1 markdown-3.10.2 markdown-it-py-4.0.0 matplotlib-3.10.8 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 numpy-2.4.2 opt_einsum-3.4.0 optree-0.18.0 pillow-12.1.1 protobuf-6.33.5 pyparsing-3.3.2 rich-14.3.2 scikit-learn-1.8.0 scipy-1.17.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.3.0 threadpoolctl-3.6.0 werkzeug-3.1.5 wheel-0.46.3 wrapt-2.1.1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2
# Out:
# 2026-02-18 15:34:03.157691: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-18 15:34:03.199844: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-18 15:34:04.407394: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
DATASET_PATH = "dataset"
IMAGE_SIZE = (160,160)
BATCH_SIZE = 16

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical"
)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1771409047.881067   16060 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)

# %%
augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %%
base_model = MobileNetV2(
    input_shape=(160,160,3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
inputs = base_model.input

x = augmentation(inputs)
x = base_model(x, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(4, activation="softmax")(x)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_160            │ (None, 5, 5, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,948 (9.87 MB)
#  Trainable params: 328,964 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=5
)
# Out:
# Epoch 1/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 53s 156ms/step - accuracy: 0.5223 - loss: 1.0153 - val_accuracy: 0.5422 - val_loss: 0.9278
# Epoch 2/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 49s 153ms/step - accuracy: 0.5551 - loss: 0.9227 - val_accuracy: 0.5352 - val_loss: 0.9342
# Epoch 3/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 48s 150ms/step - accuracy: 0.5666 - loss: 0.9019 - val_accuracy: 0.5648 - val_loss: 0.8719
# Epoch 4/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 49s 154ms/step - accuracy: 0.5736 - loss: 0.8843 - val_accuracy: 0.5727 - val_loss: 0.8619
# Epoch 5/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 55s 172ms/step - accuracy: 0.5861 - loss: 0.8765 - val_accuracy: 0.5695 - val_loss: 0.8782

# %%
base_model.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=5
)
# Out:
# Epoch 1/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 180s 508ms/step - accuracy: 0.5135 - loss: 1.1669 - val_accuracy: 0.5594 - val_loss: 0.8651
# Epoch 2/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 172s 536ms/step - accuracy: 0.5510 - loss: 0.9625 - val_accuracy: 0.5695 - val_loss: 0.8840
# Epoch 3/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 184s 574ms/step - accuracy: 0.5752 - loss: 0.8971 - val_accuracy: 0.5680 - val_loss: 0.8756
# Epoch 4/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 188s 588ms/step - accuracy: 0.5920 - loss: 0.8660 - val_accuracy: 0.5703 - val_loss: 0.8795
# Epoch 5/5
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 186s 582ms/step - accuracy: 0.5908 - loss: 0.8599 - val_accuracy: 0.5734 - val_loss: 0.8787

# %%
model.save("alzheimers_model")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.save("alzheimers_model")
#
# File ~/alzheimers_project/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/alzheimers_project/venv/lib/python3.12/site-packages/keras/src/saving/saving_api.py:114, in save_model(model, filepath, overwrite, zipped, **kwargs)
#     110 if str(filepath).endswith((".h5", ".hdf5")):
#     111     return legacy_h5_format.save_model_to_hdf5(
#     112         model, filepath, overwrite, include_optimizer
#     113     )
# --> 114 raise ValueError(
#     115     "Invalid filepath extension for saving. "
#     116     "Please add either a `.keras` extension for the native Keras "
#     117     f"format (recommended) or a `.h5` extension. "
#     118     "Use `model.export(filepath)` if you want to export a SavedModel "
#     119     "for use with TFLite/TFServing/etc. "
#     120     f"Received: filepath={filepath}."
#     121 )
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=alzheimers_model.

# %%
model.export("alzheimers_model")
# Out:
# INFO:tensorflow:Assets written to: alzheimers_model/assets
# INFO:tensorflow:Assets written to: alzheimers_model/assets
# Saved artifact at 'alzheimers_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   124320448021712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448022096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448022672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448021328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448024976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448025168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448023248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448024208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448025360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448026512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448026704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448025552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448024400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448024784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448026896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448027280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448025744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448026320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448029968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448030160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448027856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448031312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448030352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448029776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448030928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448032272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448033424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448032848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448033232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448029200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448034000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448034576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448035536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448035920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448036112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448035728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448036688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448035152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448036304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320448033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446809680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446809872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446809104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446808528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446808336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446809488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446809296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446808912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446810832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446810640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446808144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446811792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446811216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446811408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446811600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446808720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446812752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446812176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446812368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446812560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446810064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446813712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446813136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446813520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446811024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446814672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446814096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446814288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446814480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446811984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446815632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446815056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446815248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446815440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446812944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446816592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446816016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446816208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446816400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446813904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446817552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446816976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446817168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446817360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446814864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446818512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446817936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446818128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446818320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446815824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446819472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446818896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446819088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446819280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446816784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446820432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446820048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446820240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446817744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446821008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446821200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446818704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446822352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446819664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446822736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446824272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446823120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446823888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446821584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446824080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446823504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320446822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447645264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447645456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447644688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447644112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447645072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447644880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447644496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447646416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447645840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447646032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447646224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447643728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447646800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447648336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447647760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447647952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447648144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447645648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447648720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447646608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447649680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447649872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447647568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447648528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447651792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447651984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447654096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447653520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447653712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447653904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447656016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447655440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447655824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320447658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180307152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180306960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180306576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180307728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180306192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180307344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180307536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180306768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180308688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180308112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180308304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180308496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180306384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180309648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180309072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180309264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180309456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180306000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180310608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180310032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180310224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180310416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180307920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180311568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180310992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180311184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180311376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180308880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180312528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180311952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180312144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180312336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180309840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180313488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320479090192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180313296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180314640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124320180315024: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import os
print(os.listdir("alzheimers_model"))
# Out:
# ['assets', '.ipynb_checkpoints', 'fingerprint.pb', 'saved_model.pb', 'variables']
